# %% [markdown]
# # I really like this dataset! It's turning out to be my favorite of the three I've used

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %%
launch_df = pd.read_csv("data/Space_Corrected.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[161], line 1
# ----> 1 launch_df = pd.read_csv("data/Space_Corrected.csv")
#
# File c:\Users\ghodg\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:948, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     935 kwds_defaults = _refine_defaults_read(
#     936     dialect,
#     937     delimiter,
#    (...)
#     944     dtype_backend=dtype_backend,
#     945 )
#     946 kwds.update(kwds_defaults)
# --> 948 return _read(filepath_or_buffer, kwds)
#
# File c:\Users\ghodg\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:611, in _read(filepath_or_buffer, kwds)
#     608 _validate_names(kwds.get("names", None))
#     610 # Create the parser.
# --> 611 parser = TextFileReader(filepath_or_buffer, **kwds)
#     613 if chunksize or iterator:
#     614     return parser
#
# File c:\Users\ghodg\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:1448, in TextFileReader.__init__(self, f, engine, **kwds)
#    1445     self.options["has_index_names"] = kwds["has_index_names"]
#    1447 self.handles: IOHandles | None = None
# -> 1448 self._engine = self._make_engine(f, self.engine)
#
# File c:\Users\ghodg\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:1705, in TextFileReader._make_engine(self, f, engine)
#    1703     if "b" not in mode:
#    1704         mode += "b"
# -> 1705 self.handles = get_handle(
#    1706     f,
#    1707     mode,
#    1708     encoding=self.options.get("encoding", None),
#    1709     compression=self.options.get("compression", None),
#    1710     memory_map=self.options.get("memory_map", False),
#    1711     is_text=is_text,
#    1712     errors=self.options.get("encoding_errors", "strict"),
#    1713     storage_options=self.options.get("storage_options", None),
#    1714 )
#    1715 assert self.handles is not None
#    1716 f = self.handles.handle
#
# File c:\Users\ghodg\anaconda3\Lib\site-packages\pandas\io\common.py:863, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     858 elif isinstance(handle, str):
#     859     # Check whether the filename is to be opened in binary mode.
#     860     # Binary mode does not support 'encoding' and 'newline'.
#     861     if ioargs.encoding and "b" not in ioargs.mode:
#     862         # Encoding
# --> 863         handle = open(
#     864             handle,
#     865             ioargs.mode,
#     866             encoding=ioargs.encoding,
#     867             errors=errors,
#     868             newline="",
#     869         )
#     870     else:
#     871         # Binary mode
#     872         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'data/Space_Corrected.csv'

# %%
launch_df.sample(5)
# Out:
#       Unnamed: 0.1  Unnamed: 0      Company Name  \
# 3751          3751        3751  General Dynamics
# 2643          2643        2643         RVSN USSR
# 1118          1118        1118              NASA
# 4214          4214        4214      US Air Force
# 105            105         105            VKS RF
#
#                                               Location  \
# 3751         LC-576B3, Vandenberg AFB, California, USA
# 2643         Site 1/5, Baikonur Cosmodrome, Kazakhstan
# 1118        LC-39B, Kennedy Space Center, Florida, USA
# 4214  SLC-2E (75-1-1), Vandenberg AFB, California, USA
# 105            Site 133/3, Plesetsk Cosmodrome, Russia
#
#                            Datum                              Detail  \
# 3751  Thu Jul 27, 1967 19:00 UTC  Atlas-D OV1 | OV1-11/OV1-12/OV1-86
# 2643  Sat Dec 10, 1977 01:18 UTC                  Soyuz U | Soyuz 26
# 1118  Wed Dec 05, 2001 22:19 UTC   Space Shuttle Endeavour | STS-108
# 4214  Fri Jun 16, 1961 23:02 UTC  Thor DM-21 Agena-B | Discoverer 25
# 105   Fri Aug 30, 2019 14:00 UTC         Rokot/Briz KM | Cosmos 2540
#
#       Status Rocket  Rocket   Status Mission
# 3751  StatusRetired     NaN  Partial Failure
# 2643  StatusRetired     NaN          Success
# 1118  StatusRetired  450.0           Success
# 4214  StatusRetired     NaN          Success
# 105   StatusRetired   41.8           Success

# %%
launch_df
# Out:
#       Unnamed: 0.1  Unnamed: 0 Company Name  \
# 0                0           0       SpaceX
# 1                1           1         CASC
# 2                2           2       SpaceX
# 3                3           3    Roscosmos
# 4                4           4          ULA
# ...            ...         ...          ...
# 4319          4319        4319      US Navy
# 4320          4320        4320         AMBA
# 4321          4321        4321      US Navy
# 4322          4322        4322    RVSN USSR
# 4323          4323        4323    RVSN USSR
#
#                                                Location  \
# 0            LC-39A, Kennedy Space Center, Florida, USA
# 1     Site 9401 (SLS-2), Jiuquan Satellite Launch Ce...
# 2                         Pad A, Boca Chica, Texas, USA
# 3          Site 200/39, Baikonur Cosmodrome, Kazakhstan
# 4              SLC-41, Cape Canaveral AFS, Florida, USA
# ...                                                 ...
# 4319           LC-18A, Cape Canaveral AFS, Florida, USA
# 4320           LC-26A, Cape Canaveral AFS, Florida, USA
# 4321           LC-18A, Cape Canaveral AFS, Florida, USA
# 4322          Site 1/5, Baikonur Cosmodrome, Kazakhstan
# 4323          Site 1/5, Baikonur Cosmodrome, Kazakhstan
#
#                            Datum  \
# 0     Fri Aug 07, 2020 05:12 UTC
# 1     Thu Aug 06, 2020 04:01 UTC
# 2     Tue Aug 04, 2020 23:57 UTC
# 3     Thu Jul 30, 2020 21:25 UTC
# 4     Thu Jul 30, 2020 11:50 UTC
# ...                          ...
# 4319  Wed Feb 05, 1958 07:33 UTC
# 4320  Sat Feb 01, 1958 03:48 UTC
# 4321  Fri Dec 06, 1957 16:44 UTC
# 4322  Sun Nov 03, 1957 02:30 UTC
# 4323  Fri Oct 04, 1957 19:28 UTC
#
#                                             Detail  Status Rocket  Rocket  \
# 0     Falcon 9 Block 5 | Starlink V1 L9 & BlackSky   StatusActive   50.0
# 1              Long March 2D | Gaofen-9 04 & Q-SAT   StatusActive  29.75
# 2               Starship Prototype | 150 Meter Hop   StatusActive     NaN
# 3     Proton-M/Briz-M | Ekspress-80 & Ekspress-103   StatusActive   65.0
# 4                       Atlas V 541 | Perseverance   StatusActive  145.0
# ...                                            ...            ...     ...
# 4319                     Vanguard | Vanguard TV3BU  StatusRetired     NaN
# 4320                           Juno I | Explorer 1  StatusRetired     NaN
# 4321                       Vanguard | Vanguard TV3  StatusRetired     NaN
# 4322                    Sputnik 8K71PS | Sputnik-2  StatusRetired     NaN
# 4323                    Sputnik 8K71PS | Sputnik-1  StatusRetired     NaN
#
#      Status Mission
# 0           Success
# 1           Success
# 2           Success
# 3           Success
# 4           Success
# ...             ...
# 4319        Failure
# 4320        Success
# 4321        Failure
# 4322        Success
# 4323        Success
#
# [4324 rows x 9 columns]

# %%
cleaned_launch_df = launch_df.drop(['Unnamed: 0.1', 'Unnamed: 0'], axis=1)
cleaned_launch_df['Date'] = cleaned_launch_df['Datum'].str[:16]
cleaned_launch_df.drop(columns=['Datum'], inplace=True)
cleaned_launch_df['Date'] = pd.to_datetime(cleaned_launch_df['Date'], format='%a %b %d, %Y')
cleaned_launch_df
# Out:
#      Company Name                                           Location  \
# 0          SpaceX         LC-39A, Kennedy Space Center, Florida, USA
# 1            CASC  Site 9401 (SLS-2), Jiuquan Satellite Launch Ce...
# 2          SpaceX                      Pad A, Boca Chica, Texas, USA
# 3       Roscosmos       Site 200/39, Baikonur Cosmodrome, Kazakhstan
# 4             ULA           SLC-41, Cape Canaveral AFS, Florida, USA
# ...           ...                                                ...
# 4319      US Navy           LC-18A, Cape Canaveral AFS, Florida, USA
# 4320         AMBA           LC-26A, Cape Canaveral AFS, Florida, USA
# 4321      US Navy           LC-18A, Cape Canaveral AFS, Florida, USA
# 4322    RVSN USSR          Site 1/5, Baikonur Cosmodrome, Kazakhstan
# 4323    RVSN USSR          Site 1/5, Baikonur Cosmodrome, Kazakhstan
#
#                                             Detail  Status Rocket  Rocket  \
# 0     Falcon 9 Block 5 | Starlink V1 L9 & BlackSky   StatusActive   50.0
# 1              Long March 2D | Gaofen-9 04 & Q-SAT   StatusActive  29.75
# 2               Starship Prototype | 150 Meter Hop   StatusActive     NaN
# 3     Proton-M/Briz-M | Ekspress-80 & Ekspress-103   StatusActive   65.0
# 4                       Atlas V 541 | Perseverance   StatusActive  145.0
# ...                                            ...            ...     ...
# 4319                     Vanguard | Vanguard TV3BU  StatusRetired     NaN
# 4320                           Juno I | Explorer 1  StatusRetired     NaN
# 4321                       Vanguard | Vanguard TV3  StatusRetired     NaN
# 4322                    Sputnik 8K71PS | Sputnik-2  StatusRetired     NaN
# 4323                    Sputnik 8K71PS | Sputnik-1  StatusRetired     NaN
#
#      Status Mission       Date
# 0           Success 2020-08-07
# 1           Success 2020-08-06
# 2           Success 2020-08-04
# 3           Success 2020-07-30
# 4           Success 2020-07-30
# ...             ...        ...
# 4319        Failure 1958-02-05
# 4320        Success 1958-02-01
# 4321        Failure 1957-12-06
# 4322        Success 1957-11-03
# 4323        Success 1957-10-04
#
# [4324 rows x 7 columns]

# %% [markdown]
# Cleaned up the launch dataframe to what we needed, and converted the 'Datum' column that was using strings to datetime to be more useful down the line. Honestly had to do some googling since I wasn't too well versed on datetime as of yet

# %%
company_names = sorted(launch_df['Company Name'].unique())
company_names
# Out:
# ['AEB',
#  'AMBA',
#  'ASI',
#  'Arianespace',
#  "Arm??e de l'Air",
#  'Blue Origin',
#  'Boeing',
#  'CASC',
#  'CASIC',
#  'CECLES',
#  'CNES',
#  'Douglas',
#  'EER',
#  'ESA',
#  'Eurockot',
#  'ExPace',
#  'Exos',
#  'General Dynamics',
#  'IAI',
#  'ILS',
#  'IRGC',
#  'ISA',
#  'ISAS',
#  'ISRO',
#  'JAXA',
#  'KARI',
#  'KCST',
#  'Khrunichev',
#  'Kosmotras',
#  'Land Launch',
#  'Landspace',
#  'Lockheed',
#  'MHI',
#  'MITT',
#  'Martin Marietta',
#  'NASA',
#  'Northrop',
#  'OKB-586',
#  'OneSpace',
#  'RAE',
#  'RVSN USSR',
#  'Rocket Lab',
#  'Roscosmos',
#  'SRC',
#  'Sandia',
#  'Sea Launch',
#  'SpaceX',
#  'Starsem',
#  'ULA',
#  'US Air Force',
#  'US Navy',
#  'UT',
#  'VKS RF',
#  'Virgin Orbit',
#  'Yuzhmash',
#  'i-Space']

# %% [markdown]
# Was curious about all the different agencies that had launches in this dataset. Got them, and added them to a .txt file for future use

# %%
spacex_name = 'SpaceX'
spacex = cleaned_launch_df[cleaned_launch_df['Company Name'].str.match(spacex_name)]
spacex
# Out:
#     Company Name                                           Location  \
# 0         SpaceX         LC-39A, Kennedy Space Center, Florida, USA
# 2         SpaceX                      Pad A, Boca Chica, Texas, USA
# 8         SpaceX           SLC-40, Cape Canaveral AFS, Florida, USA
# 17        SpaceX           SLC-40, Cape Canaveral AFS, Florida, USA
# 20        SpaceX           SLC-40, Cape Canaveral AFS, Florida, USA
# ..           ...                                                ...
# 763       SpaceX  Omelek Island, Ronald Reagan Ballistic Missile...
# 800       SpaceX  Omelek Island, Ronald Reagan Ballistic Missile...
# 808       SpaceX  Omelek Island, Ronald Reagan Ballistic Missile...
# 879       SpaceX  Omelek Island, Ronald Reagan Ballistic Missile...
# 929       SpaceX  Omelek Island, Ronald Reagan Ballistic Missile...
#
#                                                 Detail  Status Rocket  Rocket  \
# 0         Falcon 9 Block 5 | Starlink V1 L9 & BlackSky   StatusActive   50.0
# 2                   Starship Prototype | 150 Meter Hop   StatusActive     NaN
# 8                         Falcon 9 Block 5 | ANASIS-II   StatusActive   50.0
# 17                     Falcon 9 Block 5 | GPS III SV03   StatusActive   50.0
# 20   Falcon 9 Block 5 | Starlink V1 L8 & SkySat 16 ...   StatusActive   50.0
# ..                                                 ...            ...     ...
# 763                                Falcon 1 | RazakSat  StatusRetired    7.0
# 800                                  Falcon 1 | RatSat  StatusRetired    7.0
# 808                                Falcon 1 | Flight 3  StatusRetired    7.0
# 879                                 Falcon 1 | DemoSat  StatusRetired    7.0
# 929                             Falcon 1 | FalconSat-2  StatusRetired    7.0
#
#     Status Mission       Date
# 0          Success 2020-08-07
# 2          Success 2020-08-04
# 8          Success 2020-07-20
# 17         Success 2020-06-30
# 20         Success 2020-06-13
# ..             ...        ...
# 763        Success 2009-07-14
# 800        Success 2008-09-28
# 808        Failure 2008-08-03
# 879        Failure 2007-03-21
# 929        Failure 2006-03-24
#
# [100 rows x 7 columns]

# %%
nasa_name = 'NASA'
nasa = cleaned_launch_df[cleaned_launch_df['Company Name'].str.match(nasa_name)]
nasa
# Out:
#      Company Name                                    Location  \
# 682          NASA  LC-39A, Kennedy Space Center, Florida, USA
# 687          NASA  LC-39A, Kennedy Space Center, Florida, USA
# 695          NASA  LC-39A, Kennedy Space Center, Florida, USA
# 726          NASA  LC-39A, Kennedy Space Center, Florida, USA
# 733          NASA  LC-39A, Kennedy Space Center, Florida, USA
# ...           ...                                         ...
# 4243         NASA      LC-5, Cape Canaveral AFS, Florida, USA
# 4257         NASA     LC-14, Cape Canaveral AFS, Florida, USA
# 4280         NASA     LC-14, Cape Canaveral AFS, Florida, USA
# 4296         NASA   SLC-17A, Cape Canaveral AFS, Florida, USA
# 4299         NASA   SLC-17A, Cape Canaveral AFS, Florida, USA
#
#                                             Detail  Status Rocket  Rocket  \
# 682               Space Shuttle Atlantis | STS-135  StatusRetired  450.0
# 687              Space Shuttle Endeavour | STS-134  StatusRetired  450.0
# 695              Space Shuttle Discovery | STS-133  StatusRetired  450.0
# 726               Space Shuttle Atlantis | STS-132  StatusRetired  450.0
# 733              Space Shuttle Discovery | STS-131  StatusRetired  450.0
# ...                                            ...            ...     ...
# 4243  Mercury-Redstone | Mercury-Redstone 1 (MR-1)  StatusRetired     NaN
# 4257      Atlas-D Mercury | Mercury-Atlas 1 (MA-1)  StatusRetired     NaN
# 4280                   Atlas-D Mercury | Big Joe 1  StatusRetired     NaN
# 4296                 Thor-DM 18 Able I | Pioneer 2  StatusRetired     NaN
# 4299                 Thor-DM 18 Able I | Pioneer 1  StatusRetired     NaN
#
#        Status Mission       Date
# 682           Success 2011-07-08
# 687           Success 2011-05-16
# 695           Success 2011-02-24
# 726           Success 2010-05-14
# 733           Success 2010-04-05
# ...               ...        ...
# 4243          Failure 1960-11-21
# 4257          Failure 1960-07-29
# 4280  Partial Failure 1959-09-09
# 4296          Failure 1958-11-08
# 4299  Partial Failure 1958-10-11
#
# [203 rows x 7 columns]

# %% [markdown]
# That lead me to be curious about just spacex and nasa launches

# %%
combined_names = ['SpaceX' , 'NASA', 'ULA', 'US Air Force', 'US Navy']
combined_nasa_spacex = cleaned_launch_df[cleaned_launch_df['Company Name'].str.contains('|'.join(combined_names))]
combined_nasa_spacex
# Out:
#      Company Name                                    Location  \
# 0          SpaceX  LC-39A, Kennedy Space Center, Florida, USA
# 2          SpaceX               Pad A, Boca Chica, Texas, USA
# 4             ULA    SLC-41, Cape Canaveral AFS, Florida, USA
# 8          SpaceX    SLC-40, Cape Canaveral AFS, Florida, USA
# 17         SpaceX    SLC-40, Cape Canaveral AFS, Florida, USA
# ...           ...                                         ...
# 4312      US Navy    LC-18A, Cape Canaveral AFS, Florida, USA
# 4314      US Navy    LC-18A, Cape Canaveral AFS, Florida, USA
# 4317      US Navy    LC-18A, Cape Canaveral AFS, Florida, USA
# 4319      US Navy    LC-18A, Cape Canaveral AFS, Florida, USA
# 4321      US Navy    LC-18A, Cape Canaveral AFS, Florida, USA
#
#                                             Detail  Status Rocket  Rocket  \
# 0     Falcon 9 Block 5 | Starlink V1 L9 & BlackSky   StatusActive   50.0
# 2               Starship Prototype | 150 Meter Hop   StatusActive     NaN
# 4                       Atlas V 541 | Perseverance   StatusActive  145.0
# 8                     Falcon 9 Block 5 | ANASIS-II   StatusActive   50.0
# 17                 Falcon 9 Block 5 | GPS III SV03   StatusActive   50.0
# ...                                            ...            ...     ...
# 4312                     Vanguard | Vanguard SLV-1  StatusRetired     NaN
# 4314                       Vanguard | Vanguard TV5  StatusRetired     NaN
# 4317                         Vanguard | Vanguard 1  StatusRetired     NaN
# 4319                     Vanguard | Vanguard TV3BU  StatusRetired     NaN
# 4321                       Vanguard | Vanguard TV3  StatusRetired     NaN
#
#      Status Mission       Date
# 0           Success 2020-08-07
# 2           Success 2020-08-04
# 4           Success 2020-07-30
# 8           Success 2020-07-20
# 17          Success 2020-06-30
# ...             ...        ...
# 4312        Failure 1958-05-28
# 4314        Failure 1958-04-28
# 4317        Success 1958-03-17
# 4319        Failure 1958-02-05
# 4321        Failure 1957-12-06
#
# [621 rows x 7 columns]

# %% [markdown]
# This lead to a bit of patriotism on my part. Wanted to combine all the major players that the US had in the game during this timeframe

# %%
cutoff_date = pd.to_datetime('1985-01-01') ## Fall of the Soviet Union date

america_rahh_df = combined_nasa_spacex[combined_nasa_spacex['Date'] > cutoff_date]
america_rahh_df
# Out:
#      Company Name                                    Location  \
# 0          SpaceX  LC-39A, Kennedy Space Center, Florida, USA
# 2          SpaceX               Pad A, Boca Chica, Texas, USA
# 4             ULA    SLC-41, Cape Canaveral AFS, Florida, USA
# 8          SpaceX    SLC-40, Cape Canaveral AFS, Florida, USA
# 17         SpaceX    SLC-40, Cape Canaveral AFS, Florida, USA
# ...           ...                                         ...
# 2121         NASA  LC-39A, Kennedy Space Center, Florida, USA
# 2129         NASA  LC-39A, Kennedy Space Center, Florida, USA
# 2136         NASA  LC-39A, Kennedy Space Center, Florida, USA
# 2141         NASA  LC-39A, Kennedy Space Center, Florida, USA
# 2153         NASA  LC-39A, Kennedy Space Center, Florida, USA
#
#                                             Detail  Status Rocket  Rocket  \
# 0     Falcon 9 Block 5 | Starlink V1 L9 & BlackSky   StatusActive   50.0
# 2               Starship Prototype | 150 Meter Hop   StatusActive     NaN
# 4                       Atlas V 541 | Perseverance   StatusActive  145.0
# 8                     Falcon 9 Block 5 | ANASIS-II   StatusActive   50.0
# 17                 Falcon 9 Block 5 | GPS III SV03   StatusActive   50.0
# ...                                            ...            ...     ...
# 2121           Space Shuttle Challenger | STS-51-F  StatusRetired  450.0
# 2129            Space Shuttle Discovery | STS-51-G  StatusRetired  450.0
# 2136           Space Shuttle Challenger | STS-51-B  StatusRetired  450.0
# 2141            Space Shuttle Discovery | STS-51-D  StatusRetired  450.0
# 2153            Space Shuttle Discovery | STS-51-C  StatusRetired  450.0
#
#      Status Mission       Date
# 0           Success 2020-08-07
# 2           Success 2020-08-04
# 4           Success 2020-07-30
# 8           Success 2020-07-20
# 17          Success 2020-06-30
# ...             ...        ...
# 2121        Success 1985-07-25
# 2129        Success 1985-06-17
# 2136        Success 1985-05-06
# 2141        Success 1985-04-12
# 2153        Success 1985-01-24
#
# [362 rows x 7 columns]

# %% [markdown]
# RAHHHHHH AMERICA. Decided to want to see how the US space launches compared after the fall of the soviet union. Possible research question in the making?

# %%
launch_counts = america_rahh_df.groupby(['Date', 'Company Name']).size().reset_index(name='Launch Count')
launch_counts.sample(20)
# Out:
#           Date Company Name  Launch Count
# 214 2015-09-02          ULA             1
# 56  2000-11-30         NASA             1
# 251 2017-06-03       SpaceX             1
# 177 2013-09-29       SpaceX             1
# 64  2002-04-08         NASA             1
# 51  1999-12-20         NASA             1
# 36  1997-01-12         NASA             1
# 233 2016-08-14       SpaceX             1
# 189 2014-07-02          ULA             1
# 119 2009-09-08          ULA             1
# 271 2018-02-06       SpaceX             1
# 207 2015-03-25          ULA             1
# 115 2009-07-14       SpaceX             1
# 328 2020-07-20       SpaceX             1
# 105 2009-01-18          ULA             1
# 30  1996-02-22         NASA             1
# 175 2013-08-28          ULA             1
# 28  1995-11-12         NASA             1
# 86  2007-10-17          ULA             1
# 244 2017-03-01          ULA             1

# %% [markdown]
# Wanted to count the launches by year and company name. The thought was there, but as you can see below, it didnt really work out the way I wanted it to haha

# %%
plt.figure(figsize=(12,6))
sns.lineplot(x='Date', y='Launch Count', hue='Company Name', data=launch_counts)
plt.title('Number of Launches over time by Company')
plt.xlabel('Date')
plt.ylabel('Number of launches')
plt.tight_layout()
# Out:
# c:\Users\ghodg\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\ghodg\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# # YIKES
# lets fix that real quick

# %%
grouped_counts = launch_counts.groupby(['Company Name', launch_counts['Date'].dt.year])['Launch Count'].sum().reset_index()
grouped_counts
# Out:
#    Company Name  Date  Launch Count
# 0          NASA  1992             8
# 1          NASA  1993             7
# 2          NASA  1994             7
# 3          NASA  1995             7
# 4          NASA  1996             7
# 5          NASA  1997             8
# 6          NASA  1998             5
# 7          NASA  1999             3
# 8          NASA  2000             5
# 9          NASA  2001             6
# 10         NASA  2002             5
# 11         NASA  2003             1
# 12         NASA  2005             1
# 13         NASA  2006             3
# 14         NASA  2007             3
# 15         NASA  2008             4
# 16         NASA  2009             6
# 17         NASA  2010             3
# 18         NASA  2011             3
# 19       SpaceX  2006             1
# 20       SpaceX  2007             1
# 21       SpaceX  2008             2
# 22       SpaceX  2009             1
# 23       SpaceX  2010             2
# 24       SpaceX  2012             2
# 25       SpaceX  2013             3
# 26       SpaceX  2014             6
# 27       SpaceX  2015             7
# 28       SpaceX  2016             9
# 29       SpaceX  2017            18
# 30       SpaceX  2018            21
# 31       SpaceX  2019            13
# 32       SpaceX  2020            14
# 33          ULA  2006             1
# 34          ULA  2007            13
# 35          ULA  2008             7
# 36          ULA  2009            16
# 37          ULA  2010             8
# 38          ULA  2011            11
# 39          ULA  2012            10
# 40          ULA  2013            11
# 41          ULA  2014            14
# 42          ULA  2015            12
# 43          ULA  2016            12
# 44          ULA  2017             8
# 45          ULA  2018             8
# 46          ULA  2019             5
# 47          ULA  2020             4

# %% [markdown]
# That was the issue. Had to group the launch counts into a new column. This gave me some issues, and again had to google a bit to find the current use and came to the realiziation that dt.year was a thing lol. Summed and added into the new column

# %%
plt.figure(figsize=(12,6))
sns.lineplot(x='Date', y='Launch Count', hue='Company Name', data=grouped_counts, markers='o')
plt.title('Number of Launches over time by Company')
plt.xlabel('Date')
plt.ylabel('Number of launches')
plt.tight_layout()
# Out:
# c:\Users\ghodg\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\ghodg\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# This looks okay I guess, but maybe a bar graph would be better?

# %%
plt.figure(figsize=(12,6))
sns.barplot(x='Date', y='Launch Count', hue='Company Name', data=grouped_counts, palette='Paired')
plt.title('Number of Launches over time by Company')
plt.xlabel('Date')
plt.ylabel('Number of launches')
plt.xticks(rotation=45, size=9)
plt.tight_layout()

# %% [markdown]
# Wow this actually looks professional. I really like the 'paired' palette tbh. All I did was copy the same code from above, rotated the text and changed the color palette. Seaborn > all

# %% [markdown]
# Im just now realizing this is only showing the dates directly after the year the Soviet Union fell. What about the dates leading up to it? Were we launching a lot more then slowed down with NASA?

# %% [markdown]
# Just from the above bar graph, it seems like NASA kind of stagnated a bit, at least after the fall of the USSR.

# %%
combined_names_usa_ussr = ['SpaceX' , 'NASA', 'ULA', 'US Air Force', 'US Navy', 'Roscosmos', 'RVSN USSR']
combined_usa_ussr = cleaned_launch_df[cleaned_launch_df['Company Name'].str.contains('|'.join(combined_names_usa_ussr))]
combined_usa_ussr
# Out:
#      Company Name                                      Location  \
# 0          SpaceX    LC-39A, Kennedy Space Center, Florida, USA
# 2          SpaceX                 Pad A, Boca Chica, Texas, USA
# 3       Roscosmos  Site 200/39, Baikonur Cosmodrome, Kazakhstan
# 4             ULA      SLC-41, Cape Canaveral AFS, Florida, USA
# 6       Roscosmos    Site 31/6, Baikonur Cosmodrome, Kazakhstan
# ...           ...                                           ...
# 4317      US Navy      LC-18A, Cape Canaveral AFS, Florida, USA
# 4319      US Navy      LC-18A, Cape Canaveral AFS, Florida, USA
# 4321      US Navy      LC-18A, Cape Canaveral AFS, Florida, USA
# 4322    RVSN USSR     Site 1/5, Baikonur Cosmodrome, Kazakhstan
# 4323    RVSN USSR     Site 1/5, Baikonur Cosmodrome, Kazakhstan
#
#                                             Detail  Status Rocket  Rocket  \
# 0     Falcon 9 Block 5 | Starlink V1 L9 & BlackSky   StatusActive   50.0
# 2               Starship Prototype | 150 Meter Hop   StatusActive     NaN
# 3     Proton-M/Briz-M | Ekspress-80 & Ekspress-103   StatusActive   65.0
# 4                       Atlas V 541 | Perseverance   StatusActive  145.0
# 6                      Soyuz 2.1a | Progress MS-15   StatusActive   48.5
# ...                                            ...            ...     ...
# 4317                         Vanguard | Vanguard 1  StatusRetired     NaN
# 4319                     Vanguard | Vanguard TV3BU  StatusRetired     NaN
# 4321                       Vanguard | Vanguard TV3  StatusRetired     NaN
# 4322                    Sputnik 8K71PS | Sputnik-2  StatusRetired     NaN
# 4323                    Sputnik 8K71PS | Sputnik-1  StatusRetired     NaN
#
#      Status Mission       Date
# 0           Success 2020-08-07
# 2           Success 2020-08-04
# 3           Success 2020-07-30
# 4           Success 2020-07-30
# 6           Success 2020-07-23
# ...             ...        ...
# 4317        Success 1958-03-17
# 4319        Failure 1958-02-05
# 4321        Failure 1957-12-06
# 4322        Success 1957-11-03
# 4323        Success 1957-10-04
#
# [2453 rows x 7 columns]

# %%
updated_launch_counts = combined_usa_ussr.groupby(['Date', 'Company Name']).size().reset_index(name='Launch Count')
updated_launch_counts
# Out:
#            Date Company Name  Launch Count
# 0    1957-10-04    RVSN USSR             1
# 1    1957-11-03    RVSN USSR             1
# 2    1957-12-06      US Navy             1
# 3    1958-02-05      US Navy             1
# 4    1958-03-17      US Navy             1
# ...         ...          ...           ...
# 2321 2020-07-23    Roscosmos             1
# 2322 2020-07-30    Roscosmos             1
# 2323 2020-07-30          ULA             1
# 2324 2020-08-04       SpaceX             1
# 2325 2020-08-07       SpaceX             1
#
# [2326 rows x 3 columns]

# %%
comparative_df = updated_launch_counts[updated_launch_counts['Date'] > cutoff_date]
comparative_df
# Out:
#            Date Company Name  Launch Count
# 1928 1992-01-22         NASA             1
# 1929 1992-01-24    RVSN USSR             1
# 1930 1992-02-05    RVSN USSR             1
# 1931 1992-02-17    RVSN USSR             1
# 1932 1992-03-09    RVSN USSR             1
# ...         ...          ...           ...
# 2321 2020-07-23    Roscosmos             1
# 2322 2020-07-30    Roscosmos             1
# 2323 2020-07-30          ULA             1
# 2324 2020-08-04       SpaceX             1
# 2325 2020-08-07       SpaceX             1
#
# [398 rows x 3 columns]

# %%
updated_groups = comparative_df.groupby(['Company Name', comparative_df['Date'].dt.year])['Launch Count'].sum().reset_index()
updated_groups
# Out:
#    Company Name  Date  Launch Count
# 0          NASA  1992             8
# 1          NASA  1993             7
# 2          NASA  1994             7
# 3          NASA  1995             7
# 4          NASA  1996             7
# 5          NASA  1997             8
# 6          NASA  1998             5
# 7          NASA  1999             3
# 8          NASA  2000             5
# 9          NASA  2001             6
# 10         NASA  2002             5
# 11         NASA  2003             1
# 12         NASA  2005             1
# 13         NASA  2006             3
# 14         NASA  2007             3
# 15         NASA  2008             4
# 16         NASA  2009             6
# 17         NASA  2010             3
# 18         NASA  2011             3
# 19    RVSN USSR  1992             9
# 20    RVSN USSR  1995             1
# 21    RVSN USSR  1996             1
# 22    RVSN USSR  1998             1
# 23    Roscosmos  2010             3
# 24    Roscosmos  2011             3
# 25    Roscosmos  2015             1
# 26    Roscosmos  2016            10
# 27    Roscosmos  2017             9
# 28    Roscosmos  2018            11
# 29    Roscosmos  2019            13
# 30    Roscosmos  2020             4
# 31       SpaceX  2006             1
# 32       SpaceX  2007             1
# 33       SpaceX  2008             2
# 34       SpaceX  2009             1
# 35       SpaceX  2010             2
# 36       SpaceX  2012             2
# 37       SpaceX  2013             3
# 38       SpaceX  2014             6
# 39       SpaceX  2015             7
# 40       SpaceX  2016             9
# 41       SpaceX  2017            18
# 42       SpaceX  2018            21
# 43       SpaceX  2019            13
# 44       SpaceX  2020            14
# 45          ULA  2006             1
# 46          ULA  2007            13
# 47          ULA  2008             7
# 48          ULA  2009            16
# 49          ULA  2010             8
# 50          ULA  2011            11
# 51          ULA  2012            10
# 52          ULA  2013            11
# 53          ULA  2014            14
# 54          ULA  2015            12
# 55          ULA  2016            12
# 56          ULA  2017             8
# 57          ULA  2018             8
# 58          ULA  2019             5
# 59          ULA  2020             4

# %%
plt.figure(figsize=(12,6))
sns.barplot(x='Date', y='Launch Count', hue='Company Name', data=updated_groups, palette='Paired')
plt.title('Number of Launches over time by Company')
plt.xlabel('Date')
plt.ylabel('Number of launches')
plt.xticks(rotation=45, size=10)
plt.tight_layout()
